# %%
import requests
import pandas as pd
import time
import random
import os

all_courses = []
print("🚀 BẮT ĐẦU CÀO DỮ LIỆU COURSERA...")

# 1. Khai báo Headers (COPY TỪ CURLCONVERTER DÁN VÀO ĐÂY)


cookies = {
    '__204u': '7373486190-1756868151642',
    'usprivacy': '1---',
    'OneTrustWPCCPAGoogleOptOut': 'false',
    '_ga': 'GA1.1.1074150553.1763272271',
    '_fbp': 'fb.1.1763272270777.417588635793118380',
    '_tt_enable_cookie': '1',
    '_ttp': '01KA5KF9CBHBFPY8C01NY8AFPD_.tt.1',
    'FPID': 'FPID2.2.EnxZ1zED4A1l4BsDw2yOi1U8nHfbwws6sz01sfO32Ug%3D.1763272271',
    'mutiny.user.token': '8b6d3425-65cb-471a-a530-b6c6f8c23384',
    'mutiny.user.token': '8b6d3425-65cb-471a-a530-b6c6f8c23384',
    'dpi_utmVals': '{"utm_medium__c":"coursera","utm_source__c":"header","utm_campaign__c":"website","utm_content__c":"corp-to-landing-for-campus","utm_term__c":"b-in"}',
    'dpi_utmOrigVals': '{"utm_orig_medium__c":"coursera","utm_orig_source__c":"header","utm_orig_campaign__c":"website","utm_orig_content__c":"corp-to-landing-for-campus","utm_orig_term__c":"b-in"}',
    '_mkto_trk': 'id:748-MIV-116&token:_mch-coursera.org-a26611a1ae44c94c17bfeac3f36ffd09',
    'trwv.uid': 'coursera-1763272299758-22a1b5e7%3A1',
    '_ga_G6341R8CMR': 'GS2.1.s1763277876$o2$g0$t1763277876$j60$l0$h0',
    'IR_PI': '04ed85ba-c2f0-11f0-a370-d71104d05a25%7C1763299655869',
    'CSRF3-Token': '1773721606.tbzJuQuD358yHs5g',
    'CAUTH': '1xmKfJ7_VjgNbGtud09wRV5v-fuHfkJB0Y6-xZ285SrMPDBDv1L53lS2QRtYDGssDUKMAJkd_bYzP86tsaWq7Q.J8rrvW5w21YGHEx3c7YJyg.IdWREp_XsHaJJh4pmUhqxawUqkSyTLED0EhZFMK5guf2agBZaKY2Q-4IjWgpSQx9edDn_1uAIn-Qv95VNoabF8FfkzesONV0fFtq5XrTF4TW6MrfinDPr6qs7mDHc1cI97fb4seVtwXyJPyRdTEQcORKa9Hz5u5fLV30FKvXRIXlzXIHreGJI2tpr9f-jh3fvctIAupaAitgq8m3lA0g-GOwKssiBUZfhhbftQQLSN-iNHTYB54cJ7W_P4cN5KMXebSh-ohHsQG7B9d0zJhBP_WkP2ULC4nfkIBhXa999kfMCIDQT5PenUoj0gFNU8GLk3nH28QQDHAKoedQfnEl_5yFkzo24UythcWjhnF7aZ_0MxDk18J4QRfVngryuqr86dyD3EORF0-Fx_h42R8blsLi8bbTbNWkcliMn60fhGldbkU6j6hBYRD2PFe9Tg72fcNVONy53Bv8zv_yOXBXjJ_VlhN6KhsxGY9GhVuoamOfK90cN6wY_7DOl1dP4-fS',
    '_gcl_au': '1.1.1871590587.1772857747',
    '_pxvid': '5cb47fae-19ea-11f1-8977-6372a1ecc955',
    '_px3': '609016786c09d7e192597772d6ccbf022240f69e42a9c6b92115cf74722bbf67:nnXFYxTvZLiR31Ddp0gpHM7+Y2QauM7yu8er3X2BZGnMZdK8qfIrR4Rnks/Xg2Ld6uH/IhUrz95xZj5PeE6nTw==:1000:...',
    'FPLC': 'Gi8Is3HpGqqOCBzOY9KP7c8fFxx3%2BZ8jvFwkPAIqB22WP5wQU9cVSCko3tMKjMIXzjtM%2Fw6JBbC06dnwerX4ETc6OEcUm5bRgdihRNRLH5h4lclTvSKROOjF8pq4fg%3D%3D',
    '__400v': '633e5516-d705-4d66-b7ba-014e8a07aa08',
    'ab.storage.deviceId.6b512fd4-04b5-4fd4-8b44-3f482bc8dcf9': 'g%3Ab0c2d7e3-8d96-d6ea-c6a0-b3f71b60cca0%7Ce%3Aundefined%7Cc%3A1763299757368%7Cl%3A1773387539585',
    'ab.storage.userId.6b512fd4-04b5-4fd4-8b44-3f482bc8dcf9': 'g%3A200622913%7Ce%3Aundefined%7Cc%3A1769856731218%7Cl%3A1773387539585',
    'IR_gbd': 'coursera.org',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Fri+Mar+13+2026+14%3A53%3A04+GMT%2B0700+(Indochina+Time)&version=202508.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=c99dc1fe-20fc-4f96-9584-11da5e217173&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=VN%3B48',
    'OptanonAlertBoxClosed': '2026-03-13T07:53:04.527Z',
    'ab.storage.sessionId.6b512fd4-04b5-4fd4-8b44-3f482bc8dcf9': 'g%3A0be2c710-058b-3907-d4d7-5832a49c1790%7Ce%3A1773390184844%7Cc%3A1773387539585%7Cl%3A1773388384844',
    'IR_14726': '1773388385052%7C0%7C1773388385052%7C%7C',
    '_rdt_uuid': '1763272270723.c369514c-1631-4649-9ce1-8fc346603a14',
    '_uetsid': 'a0807f001e1e11f18328dda5044fc8cb|gyxuma|2|g4b|0|2262',
    '_uetmsclkid': '_uetddb65e1801931a2144fc37a954870178',
    '_uetvid': '517117e0c2b011f0b450f30b48f1e9a6|1l4gxeo|1773388385661|9|1|bat.bing.com/p/insights/c/y',
    '_ga_ZCE2Q9YZ3F': 'GS2.1.s1773387539$o19$g1$t1773388437$j5$l0$h0',
    '_ga_7GZ59JSFWQ': 'GS2.1.s1773387539$o18$g1$t1773388437$j5$l0$h503855657',
    'ttcsid': '1773387539815::oPjjo4IRteS-1_hYNNSv.14.1773388597502.0',
    'ttcsid_CTIORPRC77UDE4D3R2FG': '1773387539815::6esAQRzgMJs0ChoIECIR.14.1773388597502.1',
    '__400vt': '1773388600350',
}

headers = {
    'accept': 'application/json',
    'accept-language': 'en',
    'apollographql-client-name': 'enterprise-learner-search',
    'apollographql-client-version': 'a0714643ae8700b8493dea977cd0f73714d2f821',
    'content-type': 'application/json',
    'operation-name': 'Search',
    'origin': 'https://www.coursera.org',
    'priority': 'u=1, i',
    'referer': 'https://www.coursera.org/programs/professional-certificate-programmes-for-public-and-private-sector-employers-in-guyana-hzl1s/browse?source=search&query=machine%20learning',
    'sec-ch-ua': '"Not:A-Brand";v="99", "Microsoft Edge";v="145", "Chromium";v="145"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Mobile Safari/537.36 Edg/145.0.0.0',
    'x-csrf3-token': '1773721606.tbzJuQuD358yHs5g',
    # 'cookie': '__204u=7373486190-1756868151642; usprivacy=1---; OneTrustWPCCPAGoogleOptOut=false; _ga=GA1.1.1074150553.1763272271; _fbp=fb.1.1763272270777.417588635793118380; _tt_enable_cookie=1; _ttp=01KA5KF9CBHBFPY8C01NY8AFPD_.tt.1; FPID=FPID2.2.EnxZ1zED4A1l4BsDw2yOi1U8nHfbwws6sz01sfO32Ug%3D.1763272271; mutiny.user.token=8b6d3425-65cb-471a-a530-b6c6f8c23384; mutiny.user.token=8b6d3425-65cb-471a-a530-b6c6f8c23384; dpi_utmVals={"utm_medium__c":"coursera","utm_source__c":"header","utm_campaign__c":"website","utm_content__c":"corp-to-landing-for-campus","utm_term__c":"b-in"}; dpi_utmOrigVals={"utm_orig_medium__c":"coursera","utm_orig_source__c":"header","utm_orig_campaign__c":"website","utm_orig_content__c":"corp-to-landing-for-campus","utm_orig_term__c":"b-in"}; _mkto_trk=id:748-MIV-116&token:_mch-coursera.org-a26611a1ae44c94c17bfeac3f36ffd09; trwv.uid=coursera-1763272299758-22a1b5e7%3A1; _ga_G6341R8CMR=GS2.1.s1763277876$o2$g0$t1763277876$j60$l0$h0; IR_PI=04ed85ba-c2f0-11f0-a370-d71104d05a25%7C1763299655869; CSRF3-Token=1773721606.tbzJuQuD358yHs5g; CAUTH=1xmKfJ7_VjgNbGtud09wRV5v-fuHfkJB0Y6-xZ285SrMPDBDv1L53lS2QRtYDGssDUKMAJkd_bYzP86tsaWq7Q.J8rrvW5w21YGHEx3c7YJyg.IdWREp_XsHaJJh4pmUhqxawUqkSyTLED0EhZFMK5guf2agBZaKY2Q-4IjWgpSQx9edDn_1uAIn-Qv95VNoabF8FfkzesONV0fFtq5XrTF4TW6MrfinDPr6qs7mDHc1cI97fb4seVtwXyJPyRdTEQcORKa9Hz5u5fLV30FKvXRIXlzXIHreGJI2tpr9f-jh3fvctIAupaAitgq8m3lA0g-GOwKssiBUZfhhbftQQLSN-iNHTYB54cJ7W_P4cN5KMXebSh-ohHsQG7B9d0zJhBP_WkP2ULC4nfkIBhXa999kfMCIDQT5PenUoj0gFNU8GLk3nH28QQDHAKoedQfnEl_5yFkzo24UythcWjhnF7aZ_0MxDk18J4QRfVngryuqr86dyD3EORF0-Fx_h42R8blsLi8bbTbNWkcliMn60fhGldbkU6j6hBYRD2PFe9Tg72fcNVONy53Bv8zv_yOXBXjJ_VlhN6KhsxGY9GhVuoamOfK90cN6wY_7DOl1dP4-fS; _gcl_au=1.1.1871590587.1772857747; _pxvid=5cb47fae-19ea-11f1-8977-6372a1ecc955; _px3=609016786c09d7e192597772d6ccbf022240f69e42a9c6b92115cf74722bbf67:nnXFYxTvZLiR31Ddp0gpHM7+Y2QauM7yu8er3X2BZGnMZdK8qfIrR4Rnks/Xg2Ld6uH/IhUrz95xZj5PeE6nTw==:1000:...; FPLC=Gi8Is3HpGqqOCBzOY9KP7c8fFxx3%2BZ8jvFwkPAIqB22WP5wQU9cVSCko3tMKjMIXzjtM%2Fw6JBbC06dnwerX4ETc6OEcUm5bRgdihRNRLH5h4lclTvSKROOjF8pq4fg%3D%3D; __400v=633e5516-d705-4d66-b7ba-014e8a07aa08; ab.storage.deviceId.6b512fd4-04b5-4fd4-8b44-3f482bc8dcf9=g%3Ab0c2d7e3-8d96-d6ea-c6a0-b3f71b60cca0%7Ce%3Aundefined%7Cc%3A1763299757368%7Cl%3A1773387539585; ab.storage.userId.6b512fd4-04b5-4fd4-8b44-3f482bc8dcf9=g%3A200622913%7Ce%3Aundefined%7Cc%3A1769856731218%7Cl%3A1773387539585; IR_gbd=coursera.org; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Mar+13+2026+14%3A53%3A04+GMT%2B0700+(Indochina+Time)&version=202508.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=c99dc1fe-20fc-4f96-9584-11da5e217173&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=VN%3B48; OptanonAlertBoxClosed=2026-03-13T07:53:04.527Z; ab.storage.sessionId.6b512fd4-04b5-4fd4-8b44-3f482bc8dcf9=g%3A0be2c710-058b-3907-d4d7-5832a49c1790%7Ce%3A1773390184844%7Cc%3A1773387539585%7Cl%3A1773388384844; IR_14726=1773388385052%7C0%7C1773388385052%7C%7C; _rdt_uuid=1763272270723.c369514c-1631-4649-9ce1-8fc346603a14; _uetsid=a0807f001e1e11f18328dda5044fc8cb|gyxuma|2|g4b|0|2262; _uetmsclkid=_uetddb65e1801931a2144fc37a954870178; _uetvid=517117e0c2b011f0b450f30b48f1e9a6|1l4gxeo|1773388385661|9|1|bat.bing.com/p/insights/c/y; _ga_ZCE2Q9YZ3F=GS2.1.s1773387539$o19$g1$t1773388437$j5$l0$h0; _ga_7GZ59JSFWQ=GS2.1.s1773387539$o18$g1$t1773388437$j5$l0$h503855657; ttcsid=1773387539815::oPjjo4IRteS-1_hYNNSv.14.1773388597502.0; ttcsid_CTIORPRC77UDE4D3R2FG=1773387539815::6esAQRzgMJs0ChoIECIR.14.1773388597502.1; __400vt=1773388600350',
}

params = {
    'opname': 'Search',
}

json_data = [
    {
        'operationName': 'Search',
        'variables': {
            'requests': [
                {
                    'entityType': 'PRODUCTS',
                    'searchContext': {
                        'searchInPrograms': {
                            'programIds': [
                                'sL3KxkJcQry9ysZCXHK8tA',
                            ],
                        },
                    },
                    'limit': 7,
                    'facetFilters': [
                        [
                            'productTypeDescription:-Short Form Content Lesson',
                        ],
                        [
                            'productTypeDescription:-Short Form Content Video',
                        ],
                    ],
                    'disableRecommender': True,
                    'maxValuesPerFacet': 1000,
                    'cursor': '0',
                    'query': 'machine learnin',
                },
                {
                    'entityType': 'PRODUCTS',
                    'searchContext': {
                        'searchInPrograms': {
                            'programIds': [
                                'sL3KxkJcQry9ysZCXHK8tA',
                            ],
                        },
                    },
                    'limit': 4,
                    'facetFilters': [
                        [
                            'productTypeDescription:-Courses',
                        ],
                        [
                            'productTypeDescription:-Guided Projects',
                        ],
                        [
                            'productTypeDescription:-Professional Certificates',
                        ],
                        [
                            'productTypeDescription:-Projects',
                        ],
                        [
                            'productTypeDescription:-Specializations',
                        ],
                    ],
                    'disableRecommender': True,
                    'maxValuesPerFacet': 1000,
                    'cursor': '0',
                    'query': 'machine learnin',
                },
            ],
        },
        'query': 'query Search($requests: [Search_Request!]!) {\n  SearchResult {\n    search(requests: $requests) {\n      ...SearchResult\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment SearchResult on Search_Result {\n  elements {\n    ...SearchHit\n    __typename\n  }\n  facets {\n    ...SearchFacets\n    __typename\n  }\n  pagination {\n    cursor\n    totalElements\n    __typename\n  }\n  totalPages\n  source {\n    indexName\n    recommender {\n      context\n      hash\n      __typename\n    }\n    __typename\n  }\n  autoAppliedFilters\n  aiSearchMetadata {\n    isEligibleForAiGeneratedSummary\n    __typename\n  }\n  __typename\n}\n\nfragment SearchHit on Search_Hit {\n  ...SearchArticleHit\n  ...SearchProductHit\n  ...SearchSuggestionHit\n  __typename\n}\n\nfragment SearchArticleHit on Search_ArticleHit {\n  aeName\n  careerField\n  category\n  createdByName\n  firstPublishedAt\n  id\n  internalContentEpic\n  internalProductLine\n  internalTargetKw\n  introduction\n  islocalized\n  lastPublishedAt\n  localizedCountryCd\n  localizedLanguageCd\n  name\n  subcategory\n  topics\n  url\n  skill: skills\n  __typename\n}\n\nfragment SearchProductHit on Search_ProductHit {\n  avgProductRating\n  cobrandingEnabled\n  completions\n  duration\n  explanationMetadata {\n    semanticScore\n    semanticMatchRank\n    lexicalScore\n    lexicalMatchRank\n    lightRankerRank\n    heavyRankerRank\n    postBusinessRulePlacementRank\n    heavyRankerFeatures\n    relevanceExplanation\n    __typename\n  }\n  id\n  imageUrl\n  isCourseFree\n  isCreditEligible\n  isNewContent\n  isPartOfCourseraPlus\n  name\n  numProductRatings\n  parentCourseName\n  parentLessonName\n  partnerLogos\n  partners\n  productCard {\n    ...SearchProductCard\n    __typename\n  }\n  productDifficultyLevel\n  productDuration\n  productType\n  skills\n  url\n  videosInLesson\n  translatedName\n  translatedSkills\n  translatedParentCourseName\n  translatedParentLessonName\n  tagline\n  fullyTranslatedLanguages\n  subtitlesOnlyLanguages\n  __typename\n}\n\nfragment SearchSuggestionHit on Search_SuggestionHit {\n  id\n  name\n  score\n  __typename\n}\n\nfragment SearchProductCard on ProductCard_ProductCard {\n  id\n  canonicalType\n  marketingProductType\n  badges\n  productTypeAttributes {\n    ... on ProductCard_Specialization {\n      ...SearchProductCardSpecialization\n      __typename\n    }\n    ... on ProductCard_Course {\n      ...SearchProductCardCourse\n      __typename\n    }\n    ... on ProductCard_Clip {\n      ...SearchProductCardClip\n      __typename\n    }\n    ... on ProductCard_Degree {\n      ...SearchProductCardDegree\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n\nfragment SearchProductCardSpecialization on ProductCard_Specialization {\n  isPathwayContent\n  __typename\n}\n\nfragment SearchProductCardCourse on ProductCard_Course {\n  isPathwayContent\n  rating\n  reviewCount\n  __typename\n}\n\nfragment SearchProductCardClip on ProductCard_Clip {\n  canonical {\n    id\n    __typename\n  }\n  __typename\n}\n\nfragment SearchProductCardDegree on ProductCard_Degree {\n  canonical {\n    id\n    __typename\n  }\n  __typename\n}\n\nfragment SearchFacets on Search_Facet {\n  name\n  nameDisplay\n  valuesAndCounts {\n    ...ValuesAndCounts\n    __typename\n  }\n  __typename\n}\n\nfragment ValuesAndCounts on Search_FacetValueAndCount {\n  count\n  value\n  valueDisplay\n  __typename\n}\n',
    },
]

#response = requests.post('https://www.coursera.org/graphql-gateway', params=params, cookies=cookies, headers=headers, json=json_data)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '[{"operationName":"Search","variables":{"requests":[{"entityType":"PRODUCTS","searchContext":{"searchInPrograms":{"programIds":["sL3KxkJcQry9ysZCXHK8tA"]}},"limit":7,"facetFilters":[["productTypeDescription:-Short Form Content Lesson"],["productTypeDescription:-Short Form Content Video"]],"disableRecommender":true,"maxValuesPerFacet":1000,"cursor":"0","query":"machine learnin"},{"entityType":"PRODUCTS","searchContext":{"searchInPrograms":{"programIds":["sL3KxkJcQry9ysZCXHK8tA"]}},"limit":4,"facetFilters":[["productTypeDescription:-Courses"],["productTypeDescription:-Guided Projects"],["productTypeDescription:-Professional Certificates"],["productTypeDescription:-Projects"],["productTypeDescription:-Specializations"]],"disableRecommender":true,"maxValuesPerFacet":1000,"cursor":"0","query":"machine learnin"}]},"query":"query Search($requests: [Search_Request!]!) {\\n  SearchResult {\\n    search(requests: $requests) {\\n      ...SearchResult\\n      __typename\\n    }\\n    __typename\\n  }\\n}\\n\\nfragment SearchResult on Search_Result {\\n  elements {\\n    ...SearchHit\\n    __typename\\n  }\\n  facets {\\n    ...SearchFacets\\n    __typename\\n  }\\n  pagination {\\n    cursor\\n    totalElements\\n    __typename\\n  }\\n  totalPages\\n  source {\\n    indexName\\n    recommender {\\n      context\\n      hash\\n      __typename\\n    }\\n    __typename\\n  }\\n  autoAppliedFilters\\n  aiSearchMetadata {\\n    isEligibleForAiGeneratedSummary\\n    __typename\\n  }\\n  __typename\\n}\\n\\nfragment SearchHit on Search_Hit {\\n  ...SearchArticleHit\\n  ...SearchProductHit\\n  ...SearchSuggestionHit\\n  __typename\\n}\\n\\nfragment SearchArticleHit on Search_ArticleHit {\\n  aeName\\n  careerField\\n  category\\n  createdByName\\n  firstPublishedAt\\n  id\\n  internalContentEpic\\n  internalProductLine\\n  internalTargetKw\\n  introduction\\n  islocalized\\n  lastPublishedAt\\n  localizedCountryCd\\n  localizedLanguageCd\\n  name\\n  subcategory\\n  topics\\n  url\\n  skill: skills\\n  __typename\\n}\\n\\nfragment SearchProductHit on Search_ProductHit {\\n  avgProductRating\\n  cobrandingEnabled\\n  completions\\n  duration\\n  explanationMetadata {\\n    semanticScore\\n    semanticMatchRank\\n    lexicalScore\\n    lexicalMatchRank\\n    lightRankerRank\\n    heavyRankerRank\\n    postBusinessRulePlacementRank\\n    heavyRankerFeatures\\n    relevanceExplanation\\n    __typename\\n  }\\n  id\\n  imageUrl\\n  isCourseFree\\n  isCreditEligible\\n  isNewContent\\n  isPartOfCourseraPlus\\n  name\\n  numProductRatings\\n  parentCourseName\\n  parentLessonName\\n  partnerLogos\\n  partners\\n  productCard {\\n    ...SearchProductCard\\n    __typename\\n  }\\n  productDifficultyLevel\\n  productDuration\\n  productType\\n  skills\\n  url\\n  videosInLesson\\n  translatedName\\n  translatedSkills\\n  translatedParentCourseName\\n  translatedParentLessonName\\n  tagline\\n  fullyTranslatedLanguages\\n  subtitlesOnlyLanguages\\n  __typename\\n}\\n\\nfragment SearchSuggestionHit on Search_SuggestionHit {\\n  id\\n  name\\n  score\\n  __typename\\n}\\n\\nfragment SearchProductCard on ProductCard_ProductCard {\\n  id\\n  canonicalType\\n  marketingProductType\\n  badges\\n  productTypeAttributes {\\n    ... on ProductCard_Specialization {\\n      ...SearchProductCardSpecialization\\n      __typename\\n    }\\n    ... on ProductCard_Course {\\n      ...SearchProductCardCourse\\n      __typename\\n    }\\n    ... on ProductCard_Clip {\\n      ...SearchProductCardClip\\n      __typename\\n    }\\n    ... on ProductCard_Degree {\\n      ...SearchProductCardDegree\\n      __typename\\n    }\\n    __typename\\n  }\\n  __typename\\n}\\n\\nfragment SearchProductCardSpecialization on ProductCard_Specialization {\\n  isPathwayContent\\n  __typename\\n}\\n\\nfragment SearchProductCardCourse on ProductCard_Course {\\n  isPathwayContent\\n  rating\\n  reviewCount\\n  __typename\\n}\\n\\nfragment SearchProductCardClip on ProductCard_Clip {\\n  canonical {\\n    id\\n    __typename\\n  }\\n  __typename\\n}\\n\\nfragment SearchProductCardDegree on ProductCard_Degree {\\n  canonical {\\n    id\\n    __typename\\n  }\\n  __typename\\n}\\n\\nfragment SearchFacets on Search_Facet {\\n  name\\n  nameDisplay\\n  valuesAndCounts {\\n    ...ValuesAndCounts\\n    __typename\\n  }\\n  __typename\\n}\\n\\nfragment ValuesAndCounts on Search_FacetValueAndCount {\\n  count\\n  value\\n  valueDisplay\\n  __typename\\n}\\n"}]'
#response = requests.post('https://www.coursera.org/graphql-gateway', params=params, cookies=cookies, headers=headers, data=data)
# --------------------------------------------------------------------------------

# 2. Vòng lặp lật trang (Cào 60 trang, mỗi trang 20 khóa = 1200 khóa)
for page in range(0, 60):
    print(f"⏳ Đang tải dữ liệu trang {page + 1}...")
    
    # --- COPY PHẦN json_data HOẶC data TỪ CURLCONVERTER DÁN VÀO ĐÂY ---
    # LƯU Ý SỐNG CÒN: Hãy tìm trong cái json_data đó tham số quy định số trang (start hoặc page).
    # Ví dụ Coursera thường dùng 'start', hãy sửa nó thành: 'start': page * 20
    json_data = {
        # ... các thông số khác giữ nguyên ...
        # 'start': page * 20  <-- BẠN PHẢI TÌM VÀ SỬA CHỖ NÀY ĐỂ NÓ LẬT TRANG
    }
    # -------------------------------------------------------------------
    
    # URL API (Cũng lấy từ Curlconverter)
    url = 'https://www.coursera.org/graphql-gateway' 

    try:
        # Gửi Request
        response = requests.post('https://www.coursera.org/graphql-gateway', params=params, cookies=cookies, headers=headers, json=json_data)
        
        if response.status_code == 200:
            data = response.json()
            
            # 3. Bóc tách JSON chính xác theo cấu trúc bạn đã gửi
            search_blocks = data[0]['data']['SearchResult']['search']
            
            for block in search_blocks:
                courses_list = block.get('elements', [])
                
                for course in courses_list:
                    # Lọc bỏ các Video lẻ tẻ, chỉ lấy Khóa học/Chứng chỉ
                    product_type = course.get('productType', '')
                    if product_type in ['COURSE', 'SPECIALIZATION', 'PROFESSIONAL_CERTIFICATE']:
                        
                        # Xử lý lấy tên Partner
                        partners_list = course.get('partners', [])
                        partner_name = partners_list[0] if len(partners_list) > 0 else "Unknown"
                        
                        # Gom vào từ điển
                        course_info = {
                            "Course_Title": course.get('name', ''),
                            "Partner": partner_name,
                            "Rating": course.get('avgProductRating', ''), 
                            "Review_Count": course.get('numProductRatings', ''), 
                            "Difficulty_Level": course.get('productDifficultyLevel', ''),
                            "Duration": course.get('productDuration', ''),
                            "Course_Type": product_type
                        }
                        all_courses.append(course_info)
        else:
            print(f"⚠️ Lỗi ở trang {page+1} - Mã lỗi: {response.status_code}")
            
    except Exception as e:
        print(f"❌ Lỗi xử lý ở trang {page+1}: {e}")
    
    # 4. Ngủ đông để lách luật Anti-bot của Coursera
    time.sleep(random.uniform(2.0, 4.5))

# 5. Xuất file CSV
print(f"✅ ĐÃ CÀO XONG! Tổng cộng lấy được: {len(all_courses)} khóa học.")
df = pd.DataFrame(all_courses)

# Tạo thư mục và lưu file
os.makedirs('raw data', exist_ok=True)
df.to_csv('raw data/coursera_raw.csv', index=False, encoding='utf-8-sig')

print("🎉 File đã lưu tại: raw data/coursera_raw.csv. HÃY GỬI NÓ CHO THÀNH VIÊN B!")
# Out:
# 🚀 BẮT ĐẦU CÀO DỮ LIỆU COURSERA...
# ⏳ Đang tải dữ liệu trang 1...
# ⚠️ Lỗi ở trang 1 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 2...
# ⚠️ Lỗi ở trang 2 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 3...
# ⚠️ Lỗi ở trang 3 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 4...
# ⚠️ Lỗi ở trang 4 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 5...
# ⚠️ Lỗi ở trang 5 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 6...
# ⚠️ Lỗi ở trang 6 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 7...
# ⚠️ Lỗi ở trang 7 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 8...
# ⚠️ Lỗi ở trang 8 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 9...
# ⚠️ Lỗi ở trang 9 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 10...
# ⚠️ Lỗi ở trang 10 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 11...
# ⚠️ Lỗi ở trang 11 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 12...
# ⚠️ Lỗi ở trang 12 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 13...
# ⚠️ Lỗi ở trang 13 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 14...
# ⚠️ Lỗi ở trang 14 - Mã lỗi: 400
# ⏳ Đang tải dữ liệu trang 15...
# ...
